# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#План-исследования" data-toc-modified-id="План-исследования-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>План исследования</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Масштабирование-признаков" data-toc-modified-id="Масштабирование-признаков-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Масштабирование признаков</a></span></li><li><span><a href="#Проверка-точности-моделей-машинного-обучения" data-toc-modified-id="Проверка-точности-моделей-машинного-обучения-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Проверка точности моделей машинного обучения</a></span><ul class="toc-item"><li><span><a href="#Decision-Tree-Classifier" data-toc-modified-id="Decision-Tree-Classifier-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Decision Tree Classifier</a></span></li><li><span><a href="#Random-Forest-Classifier" data-toc-modified-id="Random-Forest-Classifier-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Random Forest Classifier</a></span></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#AUC-ROC,-сводный-график" data-toc-modified-id="AUC-ROC,-сводный-график-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>AUC-ROC, сводный график</a></span></li></ul></li><li><span><a href="#Вывод-по-разделу-исследования" data-toc-modified-id="Вывод-по-разделу-исследования-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Вывод по разделу исследования</a></span></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Upsampling" data-toc-modified-id="Upsampling-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Upsampling</a></span><ul class="toc-item"><li><span><a href="#SMOTE" data-toc-modified-id="SMOTE-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>SMOTE</a></span></li></ul></li><li><span><a href="#Downsampling" data-toc-modified-id="Downsampling-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Downsampling</a></span><ul class="toc-item"><li><span><a href="#RandomUnderSampler" data-toc-modified-id="RandomUnderSampler-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>RandomUnderSampler</a></span></li><li><span><a href="#ClusterCentroids" data-toc-modified-id="ClusterCentroids-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>ClusterCentroids</a></span></li></ul></li><li><span><a href="#Проверка-моделей-на-сбалансированной-выборке" data-toc-modified-id="Проверка-моделей-на-сбалансированной-выборке-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Проверка моделей на сбалансированной выборке</a></span><ul class="toc-item"><li><span><a href="#Decision-Tree-Classifier" data-toc-modified-id="Decision-Tree-Classifier-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Decision Tree Classifier</a></span></li><li><span><a href="#Random-Forest-Classifier" data-toc-modified-id="Random-Forest-Classifier-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Random Forest Classifier</a></span></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#AUC-ROC,-сводный-график" data-toc-modified-id="AUC-ROC,-сводный-график-5.3.4"><span class="toc-item-num">5.3.4&nbsp;&nbsp;</span>AUC-ROC, сводный график</a></span></li></ul></li><li><span><a href="#Вывод-по-разделу-борьбы-с-дисбалансом" data-toc-modified-id="Вывод-по-разделу-борьбы-с-дисбалансом-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Вывод по разделу борьбы с дисбалансом</a></span></li></ul></li><li><span><a href="#Тестирование-моделей" data-toc-modified-id="Тестирование-моделей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Тестирование моделей</a></span><ul class="toc-item"><li><span><a href="#Dummy" data-toc-modified-id="Dummy-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Dummy</a></span></li><li><span><a href="#Decision-Tree-Classifier" data-toc-modified-id="Decision-Tree-Classifier-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Decision Tree Classifier</a></span></li><li><span><a href="#Random-Forest-Classifier" data-toc-modified-id="Random-Forest-Classifier-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Random Forest Classifier</a></span></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Logistic Regression</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Вам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Постройте модель с предельно большим значением *F1*-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59. Проверьте *F1*-меру на тестовой выборке самостоятельно.
#
# Дополнительно измеряйте *AUC-ROC*, сравнивайте её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# ## План исследования

# %% [markdown]
# 1. Подгтовка данных:
# - Посмотреть общую информацию о данных
# - Выявить и устранить дупликаты и пропуски (если это необходимо)
# - Изменить тип данных при необходимости
#
# 2. Исследование задачи
# - Предотвращение dummy ловушки
# - Разбить данные на выборки
# - Масштабирование признаков
# - Проверка точности моделей
#
# 3. Борьба с дисбалансом
# - Upsampling и Downsampling
#
# 4. Тестирование моделей
# 5. Общий вывод

# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from imblearn.under_sampling import ClusterCentroids, RandomUnderSampler
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier

from sklearn.metrics import (classification_report, accuracy_score, f1_score,
                             roc_curve, roc_auc_score)

from tqdm import tqdm

static = 12345

# %%
try:
    data = pd.read_csv('Churn.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/Churn.csv')
# try:
#     data = pd.read_csv('/datasets/Churn.csv')

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0   83807.86              1          0               1
# 2     8.0  159660.80              3          1               0
# 3     1.0       0.00              2          0               0
# 4     2.0  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.shape
# Out:
# (10000, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
col_list = data.columns
col_list
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
print('кол-во дупликатов:', data.duplicated().sum())
for col in col_list:
    print('-' * 25)
    print(col, ': кол-во NaN', data[col].isna().sum(), ', процент NaN',
          round(data[col].isna().sum() / len(data) * 100, 2), '%')
# Out:
# кол-во дупликатов: 0
# -------------------------
# RowNumber : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# CustomerId : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# Surname : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# CreditScore : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# Geography : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# Gender : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# Age : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# Tenure : кол-во NaN 909 , процент NaN 9.09 %
# -------------------------
# Balance : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# NumOfProducts : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# HasCrCard : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# IsActiveMember : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# ...

# %%
data = data.dropna().reset_index(drop=True)

# %%
col_drop = ['RowNumber', 'CustomerId', 'Surname']
data = data.drop(col_drop, axis=1)

# %%
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9091 entries, 0 to 9090
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      9091 non-null   int64
#  1   Geography        9091 non-null   object
#  2   Gender           9091 non-null   object
#  3   Age              9091 non-null   int64
#  4   Tenure           9091 non-null   float64
#  5   Balance          9091 non-null   float64
#  6   NumOfProducts    9091 non-null   int64
#  7   HasCrCard        9091 non-null   int64
#  8   IsActiveMember   9091 non-null   int64
#  9   EstimatedSalary  9091 non-null   float64
#  10  Exited           9091 non-null   int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 781.4+ KB
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42     2.0       0.00              1
# ...

# %% [markdown]
# В ходе подготовки данных были удалены данные с пропусками (столбец 'Tenure' ), поскольку заполнять их средним или медианой не считаю разумным, при условии, что данные и так сгенерированны и такой потерей можно принебречь, руководствуясь принципом `trash in - trash out`.
# Так же были удалены столбцы, не участвующие в анализе - 'RowNumber', 'CustomerId' и 'Surname'

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# Для избавления от категориальных признаков применим метод OHE - One hot encoder

# %%
data = pd.get_dummies(data, drop_first=True)
encoder = OrdinalEncoder()
data = pd.DataFrame(encoder.fit_transform(data), columns=data.columns)

# %%
# Разделяем данные на обучающую, валидационную и тестовую выборки

train_data, valid_data = train_test_split(data, test_size = 0.25, random_state = 12345)
valid_data, test_data = train_test_split(valid_data, test_size = 0.5, random_state = 12345)

print(f'Размер обучающей выборки: {train_data.shape}')
print(f'Размер валидационной выборки: {valid_data.shape}')
print(f'Размер тестовой выборки: {test_data.shape}')
# Out:
# Размер обучающей выборки: (6818, 12)
# Размер валидационной выборки: (1136, 12)
# Размер тестовой выборки: (1137, 12)

# %%
# Смотри корреляцию признаков 
data.corr()
# Out:
#                    CreditScore       Age    Tenure   Balance  NumOfProducts  \
# CreditScore           1.000000 -0.004175 -0.000290 -0.001040       0.011071
# Age                  -0.004175  1.000000 -0.013103  0.022774      -0.031947
# Tenure               -0.000290 -0.013103  1.000000 -0.003442       0.011979
# Balance              -0.001040  0.022774 -0.003442  1.000000      -0.234228
# NumOfProducts         0.011071 -0.031947  0.011979 -0.234228       1.000000
# HasCrCard            -0.003829 -0.014181  0.027232 -0.009956       0.005805
# IsActiveMember        0.030795  0.082227 -0.032178 -0.005864       0.009084
# EstimatedSalary       0.005475 -0.007131  0.010526  0.010774       0.014031
# Exited               -0.022812  0.283152 -0.016761  0.093655      -0.050271
# Geography_Germany     0.000511  0.049097 -0.003299  0.313911      -0.009476
# Geography_Spain       0.001908 -0.005631  0.000810 -0.109787       0.011903
# ...

# %%
# Строим график корреляции

plt.figure(figsize=(10, 10))
sns.heatmap(data.corr(),
            xticklabels=data.corr().columns,
            yticklabels=data.corr().columns,
            cmap='RdYlGn',
            center=0,
            annot=True)

plt.title('Корреляция значений', fontsize=14)
plt.xticks(fontsize=12, rotation=45)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ### Масштабирование признаков

# %%
# Используем Scaler

numeric = [
    'CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
    'EstimatedSalary']
scaler = StandardScaler()
scaler.fit(train_data[numeric])
# Out:
# StandardScaler()

# %%
# Масштабирование тренировочной и валидационной выборки
train_data[numeric] = scaler.transform(train_data[numeric])
valid_data[numeric] = scaler.transform(valid_data[numeric])
test_data[numeric] = scaler.transform(test_data[numeric])

display(train_data.head())
display(valid_data.head())
display(test_data.head())
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 1349    -1.039726  0.375356 -0.681448  1.150495       -0.91164        1.0
# 6740     0.297688 -0.096643 -0.681448 -0.959908        0.81060        1.0
# 6816    -1.081196 -0.191042  1.384103 -0.355680        0.81060        0.0
# 5145    -1.133034 -1.040639  1.039844 -0.959908        0.81060        0.0
# 6678    -0.479879  0.092157 -0.337189 -0.123603        0.81060        1.0
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 1349             0.0        -1.620430     0.0                1.0
# 6740             0.0        -0.596722     0.0                0.0
# 6816             1.0         0.085370     0.0                1.0
# 5145             0.0         1.670846     0.0                0.0
# 6678             1.0        -1.071568     0.0                0.0
#
#       Geography_Spain  Gender_Male
# 1349              0.0          0.0
# 6740              0.0          1.0
# ...

# %% [markdown]
# ### Проверка точности моделей машинного обучения

# %% [markdown]
# Для поиска оптимальных параметров будем использовать GridSearchCV и tqdm для понимания затрат времени

# %% [markdown]
# #### Decision Tree Classifier

# %%
# Подготовка данных для обучения моделей

train_features = train_data.drop(['Exited'], axis = 1)
train_target = train_data['Exited']

valid_features = valid_data.drop(['Exited'], axis = 1)
valid_target = valid_data['Exited']

test_features = test_data.drop(['Exited'], axis = 1)
test_target = test_data['Exited']

# %%
 создаем словарь с параметрами для поиска оптимальных значений

param_grid = {'max_depth': range(1, 15, 1)}

gscv_DTC = DecisionTreeClassifier()

# объявляем модель с указанными папаметрами
grid_search = GridSearchCV(gscv_DTC, param_grid, cv=5, n_jobs=-1)

# отображение прогрессбара при подборе каждого параметра
for params in tqdm(grid_search.param_grid):
    grid_search.fit(features_train, target_train)
print('Обучено!')

# %%
# Результат модели

DTC_score = grid_search.score(features_valid, target_valid)

print(f'Best parameters: {grid_search.best_params_}')
print(f'Best score: {grid_search.best_score_}')
print('-' * 25)

print('Точность на валидной выборке ')
print(f'Decision Tree Classifier: {DTC_score.round(4)}')

# %%
# Рассчет F1
dtc_model = DecisionTreeClassifier(max_depth=6)
dtc_model.fit(features_train, target_train)

predict_dtc = dtc_model.predict(features_valid)
f1_score_dtc = f1_score(target_valid, predict_dtc)
print(f'F1: {f1_score_dtc.round(4)}')

# %%
# Decision Tree Classifier поиск лучших значений F1, Accuracy и AUC-ROC

best_result_dtc = 0
best_f1_score_dtc = 0

# Рассчет F1 и Accuracy
for depth in range(3, 11):
    model_dtc = DecisionTreeClassifier(random_state=static, max_depth=depth)
    model_dtc.fit(train_features, train_target)

    prediction_dtc = model_dtc.predict(valid_features)
    score_train_dtc = accuracy_score(valid_target, prediction_dtc)
    f1_score_dtc = f1_score(valid_target, prediction_dtc)
    print(f'При max_depth = {depth}')
    print(f'Accuracy: {score_train_dtc}')
    print(f'F1: {f1_score_dtc}')
    print('_' * 40)
    if f1_score_dtc > best_f1_score_dtc:
        best_f1_score_dtc = f1_score_dtc
        best_result_dtc = score_train_dtc
        best_depth_dtc = depth

# Рассчет AUC-ROC
proba_dtc = model_dtc.predict_proba(valid_features)
proba_one_valid_dtc = proba_dtc[:, 1]
fpr_dtc, tpr_dtc, thresholds = roc_curve(valid_target, proba_one_valid_dtc)
auc_roc_dtc = roc_auc_score(valid_target, proba_one_valid_dtc)

print('Decision Tree Classifier')
print(f'Лучший показатель F1: {best_f1_score_dtc.round(4)} при depth = {best_depth_dtc}')
print(f'Accuracy: {best_result_dtc.round(4)}')
print(f'AUC-ROC: {auc_roc_dtc.round(4)}')
# Out:
# При max_depth = 3
# Accuracy: 0.8477112676056338
# F1: 0.44012944983818775
# ________________________________________
# При max_depth = 4
# Accuracy: 0.863556338028169
# F1: 0.5730027548209367
# ________________________________________
# При max_depth = 5
# Accuracy: 0.8609154929577465
# F1: 0.5212121212121212
# ________________________________________
# При max_depth = 6
# Accuracy: 0.8661971830985915
# F1: 0.5754189944134078
# ________________________________________
# При max_depth = 7
# Accuracy: 0.8565140845070423
# F1: 0.5744125326370757
# ________________________________________
# При max_depth = 8
# Accuracy: 0.8512323943661971
# F1: 0.5517241379310345
# ________________________________________
# При max_depth = 9
# Accuracy: 0.840669014084507
# F1: 0.5394402035623409
# ________________________________________
# При max_depth = 10
# Accuracy: 0.8283450704225352
# F1: 0.5012787723785166
# ________________________________________
# Decision Tree Classifier
# ...

# %%
plt.figure()

plt.figure(figsize=(5, 5))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(fpr_dtc, tpr_dtc)
plt.xlabel('False Positive')
plt.ylabel('True Positive')
plt.title('ROC curve')
plt.legend(('Dummy model', 'Decision Tree'))
plt.show()

# %% [markdown]
# #### Random Forest Classifier

# %% [markdown]
# Обучение и поиск оптимальных параметров в этом блоке занимает 1,5-2 минуты

# %%
# Создаем словарь с параметрами для поиска оптимальных значений

param_grid = {
    'n_estimators': range(10, 51, 10),
    'min_samples_split': range(2, 7, 2),
    'min_samples_leaf': range(2, 7, 2),
    'max_depth': range(2, 11, 2)
}

gscv_RFC = RandomForestClassifier()

# объявляем модель с указанными папаметрами
grid_search = GridSearchCV(gscv_RFC, param_grid, cv=5, n_jobs=-1)

# отображение прогрессбара при подборе каждого параметра
for params in tqdm(grid_search.param_grid):
    grid_search.fit(train_features, train_target)
print('Обучено!')

# %%
# Результат модели scoring=scorer (train_features, train_target)

RFC_score = grid_search.score(valid_features, valid_target)

print(f'Best parameters: {grid_search.best_params_}')
print(f'Best score: {grid_search.best_score_}')
print('-' * 25)

print('Точность на валидной выборке ')
print(f'Random Forest Classifier: {RFC_score.round(4)}')

# %%
# Рассчет F1

rfc_model = RandomForestClassifier(max_depth=6,
                                   min_samples_leaf=4,
                                   min_samples_split=8,
                                   n_estimators=30)
rfc_model.fit(train_features, train_target)

predict_RFC = grid_search.predict(valid_features)
f1_score_rfc = f1_score(valid_target, predict_RFC)

print(f'F1: {f1_score_rfc.round(4)}')

# %%
# Random Forest Classifier поиск лучших значений F1, Accuracy и AUC-ROC

best_result_rfc = 0
best_f1_score_rfc = 0

# Рассчет F1 и Accuracy
for depth in tqdm(range(1, 11)):
    for est in range(25, 151, 25):
        model_rfc = RandomForestClassifier(max_depth=depth,
                                           n_estimators=est,
                                           random_state=static)
        model_rfc.fit(train_features, train_target)

        prediction_rfc = model_dtc.predict(valid_features)
        accuracy_train_rfc = accuracy_score(valid_target, prediction_rfc)
        f1_score_rfc = f1_score(valid_target, prediction_rfc)
        if f1_score_rfc > best_f1_score_rfc:
            best_f1_score_rfc = f1_score_rfc
            best_accuracy_rfc = accuracy_train_rfc
            best_depth_rfc = depth
            best_est = est

# Рассчет AUC-ROC
proba_rfc = model_rfc.predict_proba(valid_features)
proba_one_valid_rfc = proba_rfc[:, 1]
fpr_rfc, tpr_rfc, thresholds = roc_curve(valid_target, proba_one_valid_rfc)
auc_roc_rfc = roc_auc_score(valid_target, proba_one_valid_rfc)

print('Random Forest Classifier')
print(f'Лучший показатель F1: {best_f1_score_rfc.round(4)} при depth = {best_depth_rfc} и n_estimators = {best_est}')
print(f'Accuracy: {best_accuracy_rfc.round(4)}')
print(f'AUC-ROC: {auc_roc_rfc.round(4)}')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:13<00:00,  1.39s/it]
# Random Forest Classifier
# Лучший показатель F1: 0.5013 при depth = 1 и n_estimators = 25
# Accuracy: 0.8283
# AUC-ROC: 0.8693

# %%
plt.figure()

plt.figure(figsize=(5, 5))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(fpr_rfc, tpr_rfc)
plt.xlabel('False Positive')
plt.ylabel('True Positive')
plt.title('ROC curve')
plt.legend(('dummy model', 'Forest Classifier'))
plt.show()

# %% [markdown]
# #### Logistic Regression

# %%
model_lr = LogisticRegression(solver='liblinear', random_state=static)
model_lr.fit(train_features, train_target)

# Рассчет Accuracy и F1
predict_lr = model_lr.predict(valid_features)
score_valid_lr = accuracy_score(valid_target, predict_lr)
f1_score_lr = f1_score(valid_target, predict_lr)

# Рассчет AUC-ROC
proba_lr = model_lr.predict_proba(valid_features)
proba_one_valid_lr = proba_lr[:, 1]
fpr_lr, tpr_lr, thresholds = roc_curve(valid_target, proba_one_valid_lr)
auc_roc_lr = roc_auc_score(valid_target, proba_one_valid_lr)

print('Logistic Regression')
print(f'Accuracy: {score_valid_lr.round(4)}')
print(f'F1: {f1_score_lr.round(4)}')
print(f'AUC-ROC: {auc_roc_lr.round(4)}')
# Out:
# Logistic Regression
# Accuracy: 0.8169
# F1: 0.3418
# AUC-ROC: 0.7808

# %%
plt.figure()

plt.figure(figsize=(5, 5))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(fpr_lr, tpr_lr)
plt.xlabel('False Positive')
plt.ylabel('True Positive')
plt.title('ROC curve')
plt.legend(('dummy model', 'Logistic Regression'))
plt.show()

# %% [markdown]
# #### AUC-ROC, сводный график

# %%
plt.figure()

plt.figure(figsize=(5, 5))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(fpr_dtc, tpr_dtc) # Decision Tree Classifier
plt.plot(fpr_rfc, tpr_rfc) # Random Forest Classifier
plt.plot(fpr_lr, tpr_lr) # Logistic Regression
plt.xlabel('False Positive')
plt.ylabel('True Positive')
plt.title('ROC curves')
plt.legend(('dummy model', 'Decision Tree', 'Random Forest', 'Logistic Regression'))
plt.show()

# %%
# Строим диаграмму баланса классов

class_frequency = train_data['Exited'].value_counts(normalize=True)
print(class_frequency)

class_frequency.plot(kind='bar', grid=True, figsize=(3, 3))
plt.xlabel('Класс')
plt.ylabel('Доля')
plt.title('Доля классов целевого признака')
# Out:
# 0.0    0.794221
# 1.0    0.205779
# Name: Exited, dtype: float64
# Text(0.5, 1.0, 'Доля классов целевого признака')

# %% [markdown]
# ### Вывод по разделу исследования

# %% [markdown]
# Рассматривая данные тремя моделями можно сделать вывод, что саммая лучшая модель оказалась `Desicion Tree Classifier`, показав следующие результаты: `F1: 0.5754`, `Accuracy: 0.8662` и значение `AUC-ROC: 0.7485`.
# Хуже всего себя проявила модель `Logistic Regression`.
#
# Из графика видно, что отношение положительных ответов к отрицательным `1/4`, что говорит нам о дисбалансе классов, всвязи с чем значения метрик могут быть искажены

# %% [markdown]
# ## Борьба с дисбалансом

# %% [markdown]
# Для борьбы с бисбалансом классов используем SMOTE и RandomUnderSampler

# %% [markdown]
# ### Upsampling

# %%
# def upsampling(features, target, repeat):
#     features_zero = features[target == 0]
#     features_one = features[target == 1]
#     target_zero = target[target == 0]
#     target_one = target[target == 1]

#     upsampled_features = pd.concat([features_zero] + [features_one] * repeat)
#     upsampled_target = pd.concat([target_zero] + [target_one] * repeat)

#     train_features_balanced, train_target_balanced  = shuffle(upsampled_features,
#                                                    upsampled_target,
#                                                    random_state=12345)

#     return train_features_balanced, train_target_balanced

# %% [markdown]
# #### SMOTE

# %%
oversample = SMOTE(random_state=static)
train_features_balanced, train_target_balanced = oversample.fit_resample(train_features, train_target)

train_features_balanced, train_target_balanced = shuffle(train_features_balanced, train_target_balanced, random_state=static)

print(train_features_balanced.shape)
print(train_target_balanced.shape)
# Out:
# (10830, 11)
# (10830,)

# %% [markdown]
# ### Downsampling

# %%
def downsampling(features, target, fraction):
    features_zero = features[target == 0]
    features_one = features[target == 1]
    target_zero = target[target == 0]
    target_one = target[target == 1]

    downsampled_features = pd.concat(
        [features_zero.sample(frac=fraction, random_state=12345)] +
        [features_one])
    downsampled_target = pd.concat(
        [target_zero.sample(frac=fraction, random_state=12345)] + [target_one])

    downsampled_features, downsampled_target = shuffle(downsampled_features,
                                                       downsampled_target,
                                                       random_state=12345)
    return downsampled_features, downsampled_target

# %%
# features_train_balanced, target_train_balanced = downsampling(features_train_upsampled, target_train_upsampled, 0.25)
features_train_balanced, target_train_balanced = downsampling(
    features_train, target_train, 0.25)

print(target_train_balanced.value_counts(normalize=1))
print(target_train_balanced.shape)

target_train_balanced.plot(kind='hist', bins=3, figsize=(2, 2))

# %% [markdown]
# #### RandomUnderSampler

# %%
rus = RandomUnderSampler(random_state=static)
train_features_balanced, train_target_balanced = rus.fit_resample(train_features_balanced, train_target_balanced)

# %% [markdown]
# #### ClusterCentroids

# %%
undersampler = ClusterCentroids()
train_features_balanced, train_target_balanced = undersampler.fit_resample(train_features_balanced, train_target_balanced)

# %%
# print(train_features_balanced.shape)
# print(train_target_balanced.shape)
class_frequency = train_target_balanced.value_counts(normalize=True)
print(class_frequency)

class_frequency.plot(kind='bar', grid=True, figsize=(3, 3))
plt.xlabel('Класс')
plt.ylabel('Доля')
plt.title('Доля классов целевого признака')
# Out:
# 0.0    0.5
# 1.0    0.5
# Name: Exited, dtype: float64
# Text(0.5, 1.0, 'Доля классов целевого признака')

# %% [markdown]
# В результате применения функции `SMOTE` и `RandomUnderSampler` получили равное распределение классов

# %% [markdown]
# Обучим модели на сбалансированной выборке

# %% [markdown]
# ### Проверка моделей на сбалансированной выборке

# %% [markdown]
# #### Decision Tree Classifier

# %%
# Decision Tree Classifier

# создаем словарь с параметрами для поиска оптимальных значений
param_grid = {'max_depth': range(1, 15, 1)}

gscv_DTC = DecisionTreeClassifier()

# объявляем модель с указанными папаметрами
grid_search = GridSearchCV(gscv_DTC, param_grid, cv=5, n_jobs=-1)

# отображение прогрессбара при подборе параметра
for params in tqdm(grid_search.param_grid):
    grid_search.fit(features_train_balanced, target_train_balanced)
print('Обучено!')

# %%
# Результаты модели

DTC_score_valid = grid_search.score(features_valid, target_valid)

print(f'Best parameters: {grid_search.best_params_}')
print(f'Best score: {grid_search.best_score_}')
print('-' * 25)

print('Точность на валидной выборке ')
print(f'Decision Tree Classifier: {DTC_score_valid.round(4)}')

# %%
dtc_model = DecisionTreeClassifier(max_depth=7, random_state=12345)
dtc_model.fit(features_train_balanced, target_train_balanced)

predict_dtc_balanced = dtc_model.predict(features_valid)
f1_score_dtc_balanced = f1_score(target_valid, predict_dtc_balanced)
print(f'F1: {f1_score_dtc_balanced.round(4)}')

# %%
# Decision Tree Classifier поиск лучших значений F1, Accuracy и AUC-ROC

best_result_dtc = 0
best_f1_score_dtc = 0

# Рассчет F1 и Accuracy
for depth in range(3, 11):
    model_dtc = DecisionTreeClassifier(random_state=static, max_depth=depth)
    model_dtc.fit(train_features_balanced, train_target_balanced)

    prediction_dtc = model_dtc.predict(valid_features)
    score_train_dtc = accuracy_score(valid_target, prediction_dtc)
    f1_score_dtc = f1_score(valid_target, prediction_dtc)
    print(f'При max_depth = {depth}')
    print(f'Accuracy: {score_train_dtc}')
    print(f'F1: {f1_score_dtc}')
    print('_' * 40)
    if f1_score_dtc > best_f1_score_dtc:
        best_f1_score_dtc = f1_score_dtc
        best_result_dtc = score_train_dtc
        best_depth_dtc = depth

# Рассчет AUC-ROC
proba_dtc = model_dtc.predict_proba(valid_features)
proba_one_valid_dtc = proba_dtc[:, 1]
fpr_dtc, tpr_dtc, thresholds = roc_curve(valid_target, proba_one_valid_dtc)
auc_roc_dtc = roc_auc_score(valid_target, proba_one_valid_dtc)

print('Decision Tree Classifier')
print(f'Лучший показатель F1: {best_f1_score_dtc.round(4)} при depth = {best_depth_dtc}')
print(f'Accuracy: {best_result_dtc.round(4)}')
print(f'AUC-ROC: {auc_roc_dtc.round(4)}')
# Out:
# При max_depth = 3
# Accuracy: 0.7359154929577465
# F1: 0.5081967213114754
# ________________________________________
# При max_depth = 4
# Accuracy: 0.7825704225352113
# F1: 0.5565529622980252
# ________________________________________
# При max_depth = 5
# Accuracy: 0.778169014084507
# F1: 0.5434782608695653
# ________________________________________
# При max_depth = 6
# Accuracy: 0.7790492957746479
# F1: 0.5724020442930153
# ________________________________________
# При max_depth = 7
# Accuracy: 0.8151408450704225
# F1: 0.5914396887159532
# ________________________________________
# При max_depth = 8
# Accuracy: 0.7878521126760564
# F1: 0.5673249551166966
# ________________________________________
# При max_depth = 9
# Accuracy: 0.7922535211267606
# F1: 0.5478927203065134
# ________________________________________
# При max_depth = 10
# Accuracy: 0.7878521126760564
# F1: 0.5444234404536862
# ________________________________________
# Decision Tree Classifier
# ...

# %%
plt.figure()

plt.figure(figsize=(5, 5))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(fpr_dtc, tpr_dtc)
plt.xlabel('False Positive')
plt.ylabel('True Positive')
plt.title('ROC curve')
plt.legend(('Dummy model', 'Decision Tree'))
plt.show()

# %% [markdown]
# #### Random Forest Classifier

# %% [markdown]
# Обучение и поиск оптимальных параметров в этом блоке занимает 1,5-2 минуты

# %%
# создаем словарь с параметрами для поиска оптимальных значений
param_grid = {
    'n_estimators': range(10, 51, 10),
    'min_samples_split': range(2, 10, 2),
    'min_samples_leaf': range(3, 8),
    'max_depth': range(2, 11, 2)
}

gscv_RFC = RandomForestClassifier()

# объявляем модель с указанными папаметрами
grid_search = GridSearchCV(gscv_RFC, param_grid, cv=5, n_jobs=-1)

# отображение прогрессбара при подборе каждого параметра
for params in tqdm(grid_search.param_grid):
    grid_search.fit(features_train_balanced, target_train_balanced)
print('Обучено!')

# %%
# Результаты модели

RFC_score_valid = grid_search.score(features_valid, target_valid)

print(f'Best parameters: {grid_search.best_params_}')
print(f'Best score: {grid_search.best_score_}')
print('-' * 25)

print('Точность на валидной выборке ')
print(f'Random Forest Classifier: {RFC_score_valid.round(4)}')

# %%
rfc_model = RandomForestClassifier(class_weight='balanced',
                                   n_estimators=30,
                                   min_samples_split=4,
                                   min_samples_leaf=3,
                                   max_depth=10,
                                   random_state=12345)
rfc_model.fit(features_train_balanced, target_train_balanced)

predict_rfc_balanced = rfc_model.predict(features_valid)
f1_score_rfc_balanced = f1_score(target_valid, predict_rfc_balanced)
print(f'F1: {f1_score_rfc_balanced.round(4)}')

# %%
# Random Forest Classifier поиск лучших значений F1, Accuracy и AUC-ROC

best_result_rfc = 0
best_f1_score_rfc = 0

# Рассчет F1 и Accuracy
for depth in tqdm(range(1,11)):
    for est in range(25, 151, 25):
        model_rfc = RandomForestClassifier(max_depth=depth,
                                           n_estimators=est,
                                           random_state=static,
                                           class_weight='balanced')
        model_rfc.fit(train_features_balanced, train_target_balanced)

        prediction_rfc = model_rfc.predict(valid_features)
        score_train_rfc = accuracy_score(valid_target, prediction_rfc)
        f1_score_rfc = f1_score(valid_target, prediction_rfc)
        if f1_score_rfc > best_f1_score_rfc:
            best_f1_score_rfc = f1_score_rfc
            best_result_rfc = score_train_rfc
            best_depth_rfc = depth
            best_est = est

# Рассчет AUC-ROC
proba_rfc = model_rfc.predict_proba(valid_features)
proba_one_valid_rfc = proba_rfc[:, 1]
fpr_rfc, tpr_rfc, thresholds = roc_curve(valid_target, proba_one_valid_rfc)
auc_roc_rfc = roc_auc_score(valid_target, proba_one_valid_rfc)

print('Random Forest Classifier')
print(f'Лучший показатель F1: {best_f1_score_rfc.round(4)} при depth = {best_depth_rfc} и n_estimators = {best_est}')
print(f'Accuracy: {best_result_rfc.round(4)}')
print(f'AUC-ROC: {auc_roc_rfc.round(4)}')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:23<00:00,  2.33s/it]
# Random Forest Classifier
# Лучший показатель F1: 0.6339 при depth = 9 и n_estimators = 125
# Accuracy: 0.8424
# AUC-ROC: 0.8668

# %%
plt.figure()

plt.figure(figsize=(5, 5))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(fpr_rfc, tpr_rfc)
plt.xlabel('False Positive')
plt.ylabel('True Positive')
plt.title('ROC curve')
plt.legend(('dummy model', 'Forest Classifier'))
plt.show()

# %% [markdown]
# #### Logistic Regression

# %%
# Logistic Regression

lr_model = LogisticRegression(class_weight='balanced', solver='liblinear', random_state=12345)
lr_model.fit(features_train_balanced, target_train_balanced)

LR_score_balanced = lr_model.score(features_train_balanced, target_train_balanced)

predict_lr_balanced = lr_model.predict(features_valid)
f1_score_lr_balanced = f1_score(target_valid, predict_lr_balanced)

print(f'Сбалансированная точность Logistic Regression: {LR_score_balanced.round(4)}')
print(f'F1: {f1_score_lr_balanced.round(4)}')

# %%
# Logistic Regression

model_lr = LogisticRegression(class_weight='balanced',solver='liblinear', random_state=static)
model_lr.fit(train_features_balanced, train_target_balanced)

# Рассчет Accuracy и F1
predict_lr = model_lr.predict(valid_features)
score_valid_lr = accuracy_score(valid_target, predict_lr)
f1_score_lr = f1_score(valid_target, predict_lr)

# Рассчет AUC-ROC
proba_lr = model_lr.predict_proba(valid_features)
proba_one_valid_lr = proba_lr[:, 1]
fpr_lr, tpr_lr, thresholds = roc_curve(valid_target, proba_one_valid_lr)
auc_roc_lr = roc_auc_score(valid_target, proba_one_valid_lr)

print('Logistic Regression')
print(f'F1: {f1_score_lr.round(4)}')
print(f'Accuracy: {score_valid_lr.round(4)}')
print(f'AUC-ROC: {auc_roc_lr.round(4)}')
# Out:
# Logistic Regression
# F1: 0.5
# Accuracy: 0.7077
# AUC-ROC: 0.7787

# %%
plt.figure()

plt.figure(figsize=(5, 5))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(fpr_lr, tpr_lr)
plt.xlabel('False Positive')
plt.ylabel('True Positive')
plt.title('ROC curve')
plt.legend(('dummy model', 'Logistic Regression'))
plt.show()

# %% [markdown]
# Рассмотрим графики AUC-ROC трех моделей сразу

# %% [markdown]
# #### AUC-ROC, сводный график

# %%
plt.figure()

plt.figure(figsize=(5, 5))
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(fpr_dtc, tpr_dtc) # Decision Tree Classifier
plt.plot(fpr_rfc, tpr_rfc) # Random Forest Classifier
plt.plot(fpr_lr, tpr_lr) # Logistic Regression
plt.xlabel('False Positive')
plt.ylabel('True Positive')
plt.title('ROC curves')
plt.legend(('dummy model', 'Decision Tree', 'Random Forest', 'Logistic Regression'))
plt.show()

# %% [markdown]
# ### Вывод по разделу борьбы с дисбалансом

# %% [markdown]
# После устранения классового дисбаланса путем применения `SMOTE` и `RandomUnderSampler`, саммой лучшей моделью оказалась `RandomForestClassifier`, достигнув `F1: 0.6339`, `Accuracy: 0.8424` и значение `AUC-ROC: 0.8668` на валидной выборке, при слеующих гиперпараметре `depth = 9` и `n_estimators = 125`.
# совсем немного уступает `DecisionTreeClassifier`:
#
# Лучший показатель F1: 0.5914 при depth = 7
# Accuracy: 0.8151
# AUC-ROC: 0.7937
#
# Однако `Logistic Regression` в тройку лучших не попадает, показав следующие результаты:
# F1: 0.5
# Accuracy: 0.7077
# AUC-ROC: 0.7787
#
# Напомню, что минимальный порог `F1: 0.59`

# %% [markdown]
# ## Тестирование моделей

# %% [markdown]
# Для контрольного сравнения будут взяты ранее подобранные оптимальные гиперпараметры моделей, при которых удалось достичь наилучших результатов F1-меры, дисбаланс классов устранен, данные масштабированы и страндартизированны. Дополнительно будет рассмотрена Dummy Model

# %% [markdown]
# ### Dummy

# %%
dummy_model = DummyClassifier(strategy='constant', constant=1)

dummy_model.fit(train_features_balanced, train_target_balanced)
f1_dummy = f1_score(dummy_model.predict(test_features), test_target)

print(f'Показатели при обучении на сбалансированной выборке')
print(f'F1: {f1_dummy.round(4)}')
# Out:
# Показатели при обучении на сбалансированной выборке
# F1: 0.3255

# %% [markdown]
# ### Decision Tree Classifier

# %% [markdown]
# Лучшим гиперпараметром для Decision Tree Classifier оказался max_depth = 7

# %%
# Decision Tree Classifier

best_result_dtc = 0
best_f1_score_dtc = 0


model_dtc = DecisionTreeClassifier(random_state=static, max_depth=7)
model_dtc.fit(train_features_balanced, train_target_balanced)

# Рассчет Accuracy и F1
prediction_dtc = model_dtc.predict(test_features)
score_test_dtc = accuracy_score(test_target, prediction_dtc)
f1_score_dtc = f1_score(test_target, prediction_dtc)

# Рассчет AUC-ROC
proba_dtc = model_dtc.predict_proba(test_features)
proba_one_test_dtc = proba_dtc[:, 1]
fpr_dtc, tpr_dtc, thresholds = roc_curve(test_target, proba_one_test_dtc)
auc_roc_dtc = roc_auc_score(test_target, proba_one_test_dtc)

print('Decision Tree Classifier')
print(f'F1: {f1_score_dtc.round(4)}')
print(f'Accuracy: {score_test_dtc.round(4)}')
print(f'AUC-ROC: {auc_roc_dtc.round(4)}')
# Out:
# Decision Tree Classifier
# F1: 0.5939
# Accuracy: 0.8135
# AUC-ROC: 0.8388

# %% [markdown]
# ### Random Forest Classifier

# %% [markdown]
# Лучшие гиперпараметры для Random Forest Classifier оказались max_depth = 9 и n_estimators = 125

# %%
# Random Forest Classifier

model_rfc = RandomForestClassifier(max_depth=9,
                                   n_estimators=125,
                                   random_state=static)
model_rfc.fit(train_features_balanced, train_target_balanced)

# Рассчет Accuracy и F1
prediction_rfc = model_rfc.predict(test_features)
score_test_rfc = accuracy_score(test_target, prediction_rfc)
f1_score_rfc = f1_score(test_target, prediction_rfc)

# Рассчет AUC-ROC
proba_rfc = model_rfc.predict_proba(test_features)
proba_one_test_rfc = proba_rfc[:, 1]
fpr_rfc, tpr_rfc, thresholds = roc_curve(test_target, proba_one_test_rfc)
auc_roc_rfc = roc_auc_score(test_target, proba_one_test_rfc)

print('Random Forest Classifier')
print(f'F1: {f1_score_rfc.round(4)}')
print(f'Accuracy: {score_test_rfc.round(4)}')
print(f'AUC-ROC: {auc_roc_rfc.round(4)}')
# Out:
# Random Forest Classifier
# F1: 0.6103
# Accuracy: 0.8338
# AUC-ROC: 0.86

# %% [markdown]
# ### Logistic Regression

# %%
# Logistic Regression

model_lr = LogisticRegression(solver='liblinear', random_state=static)
model_lr.fit(train_features_balanced, train_target_balanced)

# Рассчет Accuracy и F1
predict_lr = model_lr.predict(test_features)
score_test_lr = accuracy_score(test_target, predict_lr)
f1_score_lr = f1_score(test_target, predict_lr)

# Рассчет AUC-ROC
proba_lr = model_lr.predict_proba(test_features)
proba_one_test_lr = proba_lr[:, 1]
fpr_lr, tpr_lr, thresholds = roc_curve(test_target, proba_one_test_lr)
auc_roc_lr = roc_auc_score(test_target, proba_one_test_lr)

print('Logistic Regression')
print(f'F1: {f1_score_lr.round(4)}')
print(f'Accuracy: {score_test_lr.round(4)}')
print(f'AUC-ROC: {auc_roc_lr.round(4)}')
# Out:
# Logistic Regression
# F1: 0.5267
# Accuracy: 0.7502
# AUC-ROC: 0.7966

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# 1. Для анализа были представлены сгенерированные данные по оттоку клиентов "Бета Банка".
# Была проведена предобработка данных, в ходе кторой были удалены записи с пропусками и столбцы, не участвующие в анализе.
# Была проведена стандартизация и масштабирование данных.
#
# 2. Для устранения дисбаланса классов были применены методы `SMOTE` и `RandomUnderSampler`.
#
# 3. Лучшей моделью была определена `Random Forest Classifier`, на исправленной выборке при лучших найденных оптимальных гиперпараметрах:
#     max_depth = 9,
#     n_estimators = 125,
#     random_state = static,
#     удалось достичь следующих результатов:
#     *  `F1 мера: 0.6103`
#     *  Accuracy: 0.8338
#     *  AUC-ROC: 0.86
#
#     `Decision Tree Classifier` удалось преодолеть минимальный порог `F1: 0.59` с гиперпараметрами
#     max_depth = 7 и
#     random_state = static,
#     достигнув следующих результатов:
#     * `F1 мера: 0.5939`
#     * Accuracy: 0.8135
#     * AUC-ROC: 0.8388
#
#     `Logistic Regression` удалось достичь результата `F1: 0.5267` и `RUC-AUC: 0.7966`, так и не дотянув минимального порога `F1: 0.59`, остановившись на `F1: 0.5267`.
